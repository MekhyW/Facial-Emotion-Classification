# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import decomposition

# %%
df_angry = pd.read_csv('df_angry.csv')
df_disgusted = pd.read_csv('df_disgust.csv')
df_happy = pd.read_csv('df_happy.csv')
df_neutral = pd.read_csv('df_neutral.csv')
df_sad = pd.read_csv('df_sad.csv')
df_surprise = pd.read_csv('df_surprise.csv')

# %%
data = pd.concat([df_angry, df_disgusted, df_happy, df_neutral, df_sad, df_surprise], axis=0)

# %%
data["emotion"] = ["angry"]*len(df_angry) + ["disgusted"]*len(df_disgusted) + ["happy"]*len(df_happy) + ["neutral"]*len(df_neutral) + ["sad"]*len(df_sad) + ["surprised"]*len(df_surprise)
data["emotion"]
# Out:
# 0           angry
# 1           angry
# 2           angry
# 3           angry
# 4           angry
#           ...
# 3807    surprised
# 3808    surprised
# 3809    surprised
# 3810    surprised
# 3811    surprised
# Name: emotion, Length: 25867, dtype: object

# %%
plt.figure(figsize=(5, 3))
emotion_counts = data["emotion"].value_counts()
emotion_counts.plot(kind='bar', color='blue')
plt.title('Histogram of Emotion Occurrences')
plt.xlabel('Emotion')
plt.ylabel('Occurrences')
plt.show()

# %%
y = data["emotion"]
X = data.drop(["emotion"], axis=1)

# %%
n_components = 50
pca = decomposition.PCA(n_components=n_components)
pca.fit(X.values)

plt.figure(figsize=(5, 3))
cumulative_sum = np.cumsum(pca.explained_variance_ratio_)
plt.plot(cumulative_sum)
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.show()

print("Top Cumulative Explained Variance: ", cumulative_sum[n_components-1])
# Out:
# Top Cumulative Explained Variance:  0.9916827302501072

# %%
original_feature_names = list(X.columns)

for component_num, component in enumerate(pca.components_):
    sorted_features_indices = component.argsort()[::-1]
    top_feature_names = [original_feature_names[idx] for idx in sorted_features_indices]
    print(f"Top features for Principal Component {component_num + 1}:")
    print("Positive-contributing features:")
    for feature_name in top_feature_names[:10]:
        print(f"- {feature_name}")
    print("Negative-contributing features:")
    for feature_name in top_feature_names[-10:][::-1]:
        print(f"- {feature_name}")
    print()
# Out:
# Top features for Principal Component 1:
# Positive-contributing features:
# - 186
# - 264
# - 468
# - 646
# - 722
# - 116
# - 908
# - 576
# - 254
# - 712
# Negative-contributing features:
# - 569
# - 503
# - 665
# - 779
# - 597
# - 603
# - 737
# - 667
# - 713
# - 587
#
# Top features for Principal Component 2:
# Positive-contributing features:
# - 795
# - 345
# - 731
# - 577
# - 273
# - 759
# - 301
# - 117
# - 757
# - 299
# Negative-contributing features:
# - 186
# - 264
# - 354
# - 274
# - 468
# - 454
# - 430
# - 254
# - 116
# - 68
#
# Top features for Principal Component 3:
# Positive-contributing features:
# - 304
# - 296
# - 754
# - 350
# - 792
# - 352
# - 342
# - 800
# - 398
# - 280
# Negative-contributing features:
# - 676
# - 20
# - 218
# - 594
# - 134
# - 664
# - 206
# - 568
# - 598
# - 674
#
# Top features for Principal Component 4:
# Positive-contributing features:
# - 286
# - 312
# - 140
# - 70
# - 468
# - 454
# - 186
# - 68
# - 274
# - 254
# Negative-contributing features:
# - 744
# - 766
# - 908
# - 712
# - 646
# - 530
# - 894
# - 722
# - 528
# - 732
#
# Top features for Principal Component 5:
# Positive-contributing features:
# - 187
# - 647
# - 469
# - 909
# - 265
# - 723
# - 255
# - 713
# - 117
# - 325
# Negative-contributing features:
# - 31
# - 29
# - 33
# - 633
# - 35
# - 173
# - 635
# - 631
# - 175
# - 171
#
# Top features for Principal Component 6:
# Positive-contributing features:
# - 305
# - 755
# - 297
# - 351
# - 793
# - 801
# - 582
# - 343
# - 612
# - 353
# Negative-contributing features:
# - 163
# - 161
# - 81
# - 85
# - 149
# - 165
# - 623
# - 83
# - 621
# - 371
#
# Top features for Principal Component 7:
# Positive-contributing features:
# - 287
# - 313
# - 141
# - 71
# - 249
# - 69
# - 279
# - 143
# - 455
# - 93
# Negative-contributing features:
# - 601
# - 767
# - 745
# - 553
# - 895
# - 707
# - 587
# - 733
# - 531
# - 529
#
# Top features for Principal Component 8:
# Positive-contributing features:
# - 29
# - 31
# - 635
# - 175
# - 633
# - 173
# - 33
# - 631
# - 171
# - 35
# Negative-contributing features:
# - 353
# - 299
# - 297
# - 301
# - 305
# - 755
# - 801
# - 757
# - 273
# - 281
#
# Top features for Principal Component 9:
# Positive-contributing features:
# - 122
# - 152
# - 124
# - 156
# - 366
# - 368
# - 154
# - 292
# - 192
# - 382
# Negative-contributing features:
# - 25
# - 27
# - 23
# - 1
# - 165
# - 145
# - 77
# - 625
# - 537
# - 605
#
# Top features for Principal Component 10:
# Positive-contributing features:
# - 0
# - 22
# - 534
# - 604
# - 24
# - 30
# - 32
# - 74
# - 144
# - 28
# Negative-contributing features:
# - 794
# - 576
# - 730
# - 344
# - 758
# - 272
# - 116
# - 756
# - 722
# - 300
#
# Top features for Principal Component 11:
# Positive-contributing features:
# - 133
# - 211
# - 215
# - 593
# - 131
# - 105
# - 669
# - 673
# - 591
# - 127
# Negative-contributing features:
# - 116
# - 264
# - 186
# - 344
# - 468
# - 469
# - 255
# - 272
# - 187
# - 254
#
# Top features for Principal Component 12:
# Positive-contributing features:
# - 665
# - 569
# - 595
# - 503
# - 779
# - 677
# - 603
# - 597
# - 713
# - 667
# Negative-contributing features:
# - 953
# - 765
# - 725
# - 763
# - 947
# - 951
# - 769
# - 771
# - 797
# - 927
#
# Top features for Principal Component 13:
# Positive-contributing features:
# - 207
# - 109
# - 135
# - 43
# - 325
# - 255
# - 219
# - 469
# - 143
# - 137
# Negative-contributing features:
# - 317
# - 939
# - 315
# - 319
# - 937
# - 941
# - 311
# - 309
# - 267
# - 347
#
# Top features for Principal Component 14:
# Positive-contributing features:
# - 908
# - 646
# - 712
# - 722
# - 576
# - 778
# - 528
# - 894
# - 732
# - 802
# Negative-contributing features:
# - 592
# - 564
# - 37
# - 590
# - 950
# - 668
# - 948
# - 946
# - 401
# - 566
#
# Top features for Principal Component 15:
# Positive-contributing features:
# - 944
# - 936
# - 940
# - 942
# - 938
# - 952
# - 954
# - 946
# - 950
# - 948
# Negative-contributing features:
# - 254
# - 468
# - 324
# - 186
# - 42
# - 712
# - 264
# - 778
# - 908
# - 502
#
# Top features for Principal Component 16:
# Positive-contributing features:
# - 21
# - 219
# - 305
# - 677
# - 297
# - 135
# - 951
# - 595
# - 755
# - 351
# Negative-contributing features:
# - 215
# - 131
# - 133
# - 111
# - 673
# - 105
# - 571
# - 211
# - 593
# - 591
#
# Top features for Principal Component 17:
# Positive-contributing features:
# - 676
# - 594
# - 20
# - 598
# - 674
# - 666
# - 302
# - 664
# - 218
# - 677
# Negative-contributing features:
# - 954
# - 946
# - 948
# - 952
# - 950
# - 944
# - 0
# - 942
# - 22
# - 936
#
# Top features for Principal Component 18:
# Positive-contributing features:
# - 944
# - 938
# - 936
# - 942
# - 940
# - 21
# - 219
# - 677
# - 135
# - 595
# Negative-contributing features:
# - 117
# - 345
# - 265
# - 577
# - 138
# - 723
# - 795
# - 208
# - 216
# - 273
#
# Top features for Principal Component 19:
# Positive-contributing features:
# - 582
# - 584
# - 612
# - 616
# - 122
# - 152
# - 124
# - 156
# - 750
# - 648
# Negative-contributing features:
# - 0
# - 22
# - 534
# - 74
# - 24
# - 604
# - 144
# - 26
# - 76
# - 536
#
# Top features for Principal Component 20:
# Positive-contributing features:
# - 952
# - 954
# - 946
# - 950
# - 700
# - 698
# - 904
# - 948
# - 906
# - 902
# Negative-contributing features:
# - 668
# - 592
# - 564
# - 586
# - 566
# - 590
# - 210
# - 132
# - 672
# - 104
#
# Top features for Principal Component 21:
# Positive-contributing features:
# - 210
# - 132
# - 104
# - 126
# - 130
# - 106
# - 214
# - 952
# - 446
# - 448
# Negative-contributing features:
# - 668
# - 938
# - 592
# - 586
# - 944
# - 564
# - 1
# - 23
# - 936
# - 535
#
# Top features for Principal Component 22:
# Positive-contributing features:
# - 1
# - 75
# - 535
# - 23
# - 145
# - 605
# - 29
# - 25
# - 31
# - 954
# Negative-contributing features:
# - 583
# - 613
# - 123
# - 585
# - 153
# - 617
# - 125
# - 157
# - 751
# - 575
#
# Top features for Principal Component 23:
# Positive-contributing features:
# - 286
# - 42
# - 108
# - 222
# - 324
# - 136
# - 794
# - 206
# - 734
# - 142
# Negative-contributing features:
# - 37
# - 167
# - 627
# - 132
# - 568
# - 214
# - 344
# - 744
# - 130
# - 502
#
# Top features for Principal Component 24:
# Positive-contributing features:
# - 680
# - 692
# - 694
# - 744
# - 234
# - 530
# - 522
# - 896
# - 236
# - 222
# Negative-contributing features:
# - 952
# - 950
# - 946
# - 954
# - 948
# - 938
# - 940
# - 936
# - 944
# - 123
#
# Top features for Principal Component 25:
# Positive-contributing features:
# - 215
# - 111
# - 677
# - 387
# - 19
# - 595
# - 21
# - 491
# - 37
# - 744
# Negative-contributing features:
# - 773
# - 775
# - 319
# - 321
# - 287
# - 771
# - 124
# - 156
# - 152
# - 777
#
# Top features for Principal Component 26:
# Positive-contributing features:
# - 948
# - 132
# - 210
# - 765
# - 761
# - 763
# - 214
# - 513
# - 927
# - 954
# Negative-contributing features:
# - 319
# - 773
# - 317
# - 321
# - 775
# - 771
# - 941
# - 323
# - 744
# - 777
#
# Top features for Principal Component 27:
# Positive-contributing features:
# - 952
# - 773
# - 950
# - 672
# - 592
# - 771
# - 946
# - 319
# - 775
# - 317
# Negative-contributing features:
# - 680
# - 692
# - 744
# - 694
# - 745
# - 530
# - 286
# - 522
# - 896
# - 767
#
# Top features for Principal Component 28:
# Positive-contributing features:
# - 123
# - 153
# - 125
# - 300
# - 157
# - 272
# - 820
# - 37
# - 644
# - 293
# Negative-contributing features:
# - 575
# - 115
# - 821
# - 373
# - 758
# - 756
# - 730
# - 865
# - 425
# - 645
#
# Top features for Principal Component 29:
# Positive-contributing features:
# - 950
# - 946
# - 948
# - 952
# - 954
# - 211
# - 127
# - 105
# - 107
# - 133
# Negative-contributing features:
# - 593
# - 669
# - 591
# - 565
# - 673
# - 587
# - 571
# - 938
# - 567
# - 744
#
# Top features for Principal Component 30:
# Positive-contributing features:
# - 34
# - 32
# - 583
# - 613
# - 30
# - 585
# - 617
# - 28
# - 168
# - 630
# Negative-contributing features:
# - 744
# - 766
# - 153
# - 123
# - 125
# - 530
# - 157
# - 372
# - 193
# - 191
#
# Top features for Principal Component 31:
# Positive-contributing features:
# - 222
# - 286
# - 234
# - 70
# - 62
# - 312
# - 452
# - 236
# - 456
# - 669
# Negative-contributing features:
# - 938
# - 936
# - 940
# - 944
# - 942
# - 42
# - 133
# - 211
# - 108
# - 214
#
# Top features for Principal Component 32:
# Positive-contributing features:
# - 773
# - 771
# - 940
# - 942
# - 936
# - 938
# - 944
# - 215
# - 775
# - 319
# Negative-contributing features:
# - 950
# - 767
# - 755
# - 948
# - 744
# - 946
# - 305
# - 601
# - 801
# - 297
#
# Top features for Principal Component 33:
# Positive-contributing features:
# - 286
# - 942
# - 744
# - 312
# - 944
# - 936
# - 940
# - 766
# - 938
# - 673
# Negative-contributing features:
# - 256
# - 490
# - 242
# - 133
# - 386
# - 131
# - 466
# - 110
# - 105
# - 215
#
# Top features for Principal Component 34:
# Positive-contributing features:
# - 696
# - 938
# - 745
# - 694
# - 767
# - 944
# - 286
# - 936
# - 940
# - 601
# Negative-contributing features:
# - 744
# - 952
# - 766
# - 950
# - 946
# - 954
# - 111
# - 215
# - 530
# - 948
#
# Top features for Principal Component 35:
# Positive-contributing features:
# - 571
# - 264
# - 673
# - 186
# - 116
# - 591
# - 354
# - 34
# - 430
# - 593
# Negative-contributing features:
# - 206
# - 134
# - 218
# - 108
# - 20
# - 208
# - 304
# - 676
# - 138
# - 296
#
# Top features for Principal Component 36:
# Positive-contributing features:
# - 568
# - 664
# - 502
# - 596
# - 666
# - 353
# - 602
# - 297
# - 21
# - 299
# Negative-contributing features:
# - 37
# - 108
# - 627
# - 42
# - 167
# - 802
# - 948
# - 136
# - 722
# - 813
#
# Top features for Principal Component 37:
# Positive-contributing features:
# - 35
# - 169
# - 629
# - 694
# - 363
# - 696
# - 811
# - 33
# - 27
# - 692
# Negative-contributing features:
# - 805
# - 535
# - 175
# - 75
# - 635
# - 357
# - 637
# - 29
# - 926
# - 167
#
# Top features for Principal Component 38:
# Positive-contributing features:
# - 744
# - 766
# - 724
# - 796
# - 828
# - 764
# - 926
# - 826
# - 768
# - 35
# Negative-contributing features:
# - 694
# - 696
# - 692
# - 898
# - 698
# - 948
# - 900
# - 954
# - 939
# - 941
#
# Top features for Principal Component 39:
# Positive-contributing features:
# - 286
# - 312
# - 266
# - 486
# - 346
# - 380
# - 310
# - 378
# - 314
# - 70
# Negative-contributing features:
# - 236
# - 238
# - 234
# - 458
# - 942
# - 240
# - 35
# - 169
# - 460
# - 629
#
# Top features for Principal Component 40:
# Positive-contributing features:
# - 3
# - 167
# - 39
# - 627
# - 549
# - 89
# - 251
# - 114
# - 709
# - 37
# Negative-contributing features:
# - 17
# - 337
# - 19
# - 703
# - 245
# - 13
# - 825
# - 377
# - 264
# - 687
#
# Top features for Principal Component 41:
# Positive-contributing features:
# - 773
# - 775
# - 319
# - 771
# - 321
# - 777
# - 317
# - 167
# - 627
# - 933
# Negative-contributing features:
# - 941
# - 939
# - 937
# - 943
# - 945
# - 953
# - 951
# - 947
# - 949
# - 955
#
# Top features for Principal Component 42:
# Positive-contributing features:
# - 574
# - 114
# - 820
# - 86
# - 372
# - 546
# - 872
# - 644
# - 212
# - 864
# Negative-contributing features:
# - 754
# - 304
# - 800
# - 296
# - 756
# - 352
# - 758
# - 298
# - 350
# - 792
#
# Top features for Principal Component 43:
# Positive-contributing features:
# - 319
# - 317
# - 941
# - 321
# - 939
# - 937
# - 943
# - 725
# - 927
# - 765
# Negative-contributing features:
# - 953
# - 947
# - 949
# - 951
# - 955
# - 291
# - 307
# - 311
# - 309
# - 267
#
# Top features for Principal Component 44:
# Positive-contributing features:
# - 19
# - 745
# - 767
# - 17
# - 939
# - 937
# - 941
# - 345
# - 599
# - 667
# Negative-contributing features:
# - 571
# - 287
# - 591
# - 673
# - 261
# - 108
# - 325
# - 43
# - 71
# - 42
#
# Top features for Principal Component 45:
# Positive-contributing features:
# - 749
# - 747
# - 19
# - 761
# - 208
# - 507
# - 138
# - 127
# - 141
# - 502
# Negative-contributing features:
# - 745
# - 111
# - 215
# - 767
# - 531
# - 324
# - 254
# - 387
# - 42
# - 305
#
# Top features for Principal Component 46:
# Positive-contributing features:
# - 945
# - 695
# - 677
# - 107
# - 595
# - 105
# - 264
# - 697
# - 955
# - 665
# Negative-contributing features:
# - 19
# - 17
# - 745
# - 287
# - 209
# - 139
# - 575
# - 267
# - 767
# - 137
#
# Top features for Principal Component 47:
# Positive-contributing features:
# - 299
# - 287
# - 353
# - 313
# - 301
# - 297
# - 341
# - 281
# - 597
# - 503
# Negative-contributing features:
# - 731
# - 759
# - 795
# - 502
# - 778
# - 135
# - 729
# - 254
# - 219
# - 789
#
# Top features for Principal Component 48:
# Positive-contributing features:
# - 111
# - 272
# - 215
# - 255
# - 325
# - 344
# - 276
# - 43
# - 18
# - 601
# Negative-contributing features:
# - 324
# - 254
# - 287
# - 313
# - 468
# - 778
# - 42
# - 502
# - 712
# - 141
#
# Top features for Principal Component 49:
# Positive-contributing features:
# - 773
# - 771
# - 775
# - 939
# - 945
# - 937
# - 943
# - 941
# - 777
# - 313
# Negative-contributing features:
# - 319
# - 321
# - 317
# - 323
# - 953
# - 947
# - 493
# - 949
# - 955
# - 315
#
# Top features for Principal Component 50:
# Positive-contributing features:
# - 19
# - 17
# - 289
# - 291
# - 773
# - 775
# - 730
# - 47
# - 137
# - 209
# Negative-contributing features:
# - 21
# - 677
# - 219
# - 135
# - 908
# - 595
# - 712
# - 951
# - 778
# - 953

# %%
principal_components = pca.transform(X)
# Out:
# c:\Users\felip\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:402: UserWarning: X has feature names, but PCA was fitted without feature names
#   warnings.warn(

# %%
pc_df = pd.DataFrame(data=principal_components, columns=[f"PC{i+1}" for i in range(n_components)])

# %%
pc_df["target"] = y.to_list()

# %%
pc_df.to_csv("principal_components_with_labels.csv", index=False)

# %%
import joblib

joblib.dump(pca, 'pca_model.pkl')
# Out:
# ['pca_model.pkl']

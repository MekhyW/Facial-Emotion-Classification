# %%
import pandas as pd
from tpot import TPOTClassifier
from sklearn.model_selection import train_test_split

# %%
import psutil
from dask.distributed import Client
client = Client(n_workers=psutil.cpu_count(logical=True), threads_per_worker=1)
client
# Out:
# C:\Users\felip\AppData\Roaming\Python\Python310\site-packages\distributed\node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 53517 instead
#   warnings.warn(
# c:\Program Files\Python310\lib\contextlib.py:142: UserWarning: Creating scratch directories is taking a surprisingly long time. (2.06s) This is often due to running workers on a network file system. Consider specifying a local-directory to point workers to write scratch data to a local disk.
#   next(self.gen)
# <Client: 'tcp://127.0.0.1:53519' processes=16 threads=16, memory=15.69 GiB>

# %%
import dask

dask.config.set({'distributed.scheduler.allowed-failures': 100});

# %%
df_angry = pd.read_csv('df_angry.csv')
df_disgusted = pd.read_csv('df_disgust.csv')
df_happy = pd.read_csv('df_happy.csv')
df_neutral = pd.read_csv('df_neutral.csv')
df_sad = pd.read_csv('df_sad.csv')
df_surprise = pd.read_csv('df_surprise.csv')
data = pd.concat([df_angry, df_disgusted, df_happy, df_neutral, df_sad, df_surprise], axis=0)
data["emotion"] = ["angry"]*len(df_angry) + ["disgusted"]*len(df_disgusted) + ["happy"]*len(df_happy) + ["neutral"]*len(df_neutral) + ["sad"]*len(df_sad) + ["surprised"]*len(df_surprise)

# %%
X_train, X_test, y_train, y_test = train_test_split(data.drop(columns=["emotion"]), data["emotion"], test_size=0.01, random_state=42)

# %%
tp = TPOTClassifier(
    generations=5,
    population_size=20,
    verbosity=2,
    random_state=42,
    n_jobs=-1,
    cv=5,
    use_dask=True,
)

# %%
tp.fit(X_train, y_train)
# Out:
# Warning: xgboost.XGBClassifier is not available and will not be used by TPOT.
# Optimization Progress:   0%|          | 0/120 [00:00<?, ?pipeline/s]
# 2024-07-05 16:22:04,886 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:53560 (pid=7540) exceeded 95% memory budget. Restarting...
# 2024-07-05 16:22:05,199 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:53578 (pid=1856) exceeded 95% memory budget. Restarting...
# 2024-07-05 16:22:06,038 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:53560' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'cv-parameters-a6d4fce7b3cf850dc0afe3899e3d5ef7', 'cv-split-91d9a0cbcea6dfbf98ee3efa3b44ce4a', 'cv-n-samples-91d9a0cbcea6dfbf98ee3efa3b44ce4a', 'cv-parameters-18c4ccf844f47ae0f47395cf02cbda85', 'sgdclassifier-16db390d031f38c28dbc29efea8a9ff7', 'cv-parameters-5cd25531853821b40f1aee44976e2129', 'cv-parameters-c56db623cbc344c8d5f4baf57280a608', 'cv-parameters-bf60ed9bd4605bf8ab30d418f9c5193f'} (stimulus_id='handle-worker-cleanup-1720207326.038432')
# 2024-07-05 16:22:06,883 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:53578' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'cv-split-4c879613417b5555942225fa6facf2b2', 'decisiontreeclassifier-ecb02f79a4f05d0c813185dbd8b2eaab', 'cv-split-c56db623cbc344c8d5f4baf57280a608', 'sgdclassifier-bf60ed9bd4605bf8ab30d418f9c5193f', 'cv-split-a6d4fce7b3cf850dc0afe3899e3d5ef7', 'cv-n-samples-5b384e4c4ee0030be2f371cc40abb455', 'cv-parameters-71fdc8a0cd8f6bab946a7087e071810b', 'cv-split-ed34800df820d116b976370d2ebbe147', 'cv-n-samples-4c879613417b5555942225fa6facf2b2', 'DataFrame-994167552b2f6e6c84ffec63e7c78477'} (stimulus_id='handle-worker-cleanup-1720207326.8834126')
# 2024-07-05 16:22:13,976 - distributed.nanny - WARNING - Restarting worker
# 2024-07-05 16:22:14,039 - distributed.nanny - WARNING - Restarting worker
# 2024-07-05 16:22:36,260 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:
- distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:53631 (pid=19856) exceeded 95% memory budget. Restarting...
# 2024-07-05 16:22:47,152 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:53575 (pid=7040) is slow to terminate; trying again
# 2024-07-05 16:22:47,593 - distributed.nanny - WARNING - Restarting worker
# 2024-07-05 16:22:57,950 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:53575 (pid=7040) is slow to terminate; trying again
# 2024-07-05 16:22:57,977 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:53631' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'cv-split-5c4ba7eefcbf1fd5005aece7948a71aa', 'cv-parameters-80974075bffdf5632bef44b376898b32', 'kneighborsclassifier-18c4ccf844f47ae0f47395cf02cbda85', 'cv-n-samples-5c4ba7eefcbf1fd5005aece7948a71aa', 'cv-n-samples-5b384e4c4ee0030be2f371cc40abb455', 'decisiontreeclassifier-c56db623cbc344c8d5f4baf57280a608'} (stimulus_id='handle-worker-cleanup-1720207377.9768772')
# 2024-07-05 16:23:15,488 - distributed.scheduler - ERROR - Task ('decisiontreeclassifier-fit-5b384e4c4ee0030be2f371cc40abb455', 0, 4) marked as failed because 4 workers died while trying to run it
# 2024-07-05 16:23:15,489 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:53575' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'kneighborsclassifier-71fdc8a0cd8f6bab946a7087e071810b', 'fastica-4c879613417b5555942225fa6facf2b2', 'cv-parameters-4c879613417b5555942225fa6facf2b2'} (stimulus_id='handle-worker-cleanup-1720207395.4887931')
# Task exception was never retrieved
# future: <Task finished name='Task-1602746' coro=<Nanny._log_event() done, defined at C:\Users\felip\AppData\Roaming\Python\Python310\site-packages\distributed\nanny.py:632> exception=CommClosedError('in <TCP (closed) ConnectionPool.log_event local=tcp://127.0.0.1:53862 remote=tcp://127.0.0.1:53519>: Stream is closed')>
# Traceback (most recent call last):
#   File "C:\Users\felip\AppData\Roaming\Python\Python310\site-packages\distributed\comm\tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\felip\AppData\Roaming\Python\Python310\site-packages\distributed\nanny.py", line 633, in _log_event
#     await self.scheduler.log_event(
#   File "C:\Users\felip\AppData\Roaming\Python\Python310\site-packages\distributed\core.py", line 1395, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "C:\Users\felip\AppData\Roaming\Python\Python310\site-packages\distributed\core.py", line 1154, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "C:\Users\felip\AppData\Roaming\Python\Python310\site-packages\distributed\comm\tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "C:\Users\felip\AppData\Roaming\Python\Python310\site-packages\distributed\comm\tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.log_event local=tcp://127.0.0.1:53862 remote=tcp://127.0.0.1:53519>: Stream is closed
# 2024-07-05 16:23:15,842 - distributed.nanny - WARNING - Restarting worker
# 2024-07-05 16:23:15,848 - distributed.nanny - WARNING - Restarting worker
# Future exception was never retrieved
# future: <Future finished exception=PermissionError(13, 'Acesso negado', None, 5, None)>
# Traceback (most recent call last):
#   File "C:\Users\felip\AppData\Roaming\Python\Python310\site-packages\distributed\process.py", line 55, in _call_and_set_future
#     res = func(*args, **kwargs)
#   File "c:\Program Files\Python310\lib\multiprocessing\process.py", line 140, in kill
#     self._popen.kill()
#   File "c:\Program Files\Python310\lib\multiprocessing\popen_spawn_win32.py", line 123, in terminate
#     _winapi.TerminateProcess(int(self._handle), TERMINATE)
# PermissionError: [WinError 5] Acesso negado
# Future exception was never retrieved
# future: <Future finished exception=PermissionError(13, 'Acesso negado', None, 5, None)>
# Traceback (most recent call last):
#   File "C:\Users\felip\AppData\Roaming\Python\Python310\site-packages\distributed\process.py", line 55, in _call_and_set_future
#     res = func(*args, **kwargs)
#   File "c:\Program Files\Python310\lib\multiprocessing\process.py", line 140, in kill
#     self._popen.kill()
#   File "c:\Program Files\Python310\lib\multiprocessing\popen_spawn_win32.py", line 123, in terminate
#     _winapi.TerminateProcess(int(self._handle), TERMINATE)
# PermissionError: [WinError 5] Acesso negado
# Future exception was never retrieved
# future: <Future finished exception=PermissionError(13, 'Acesso negado', None, 5, None)>
# Traceback (most recent call last):
#   File "C:\Users\felip\AppData\Roaming\Python\Python310\site-packages\distributed\process.py", line 55, in _call_and_set_future
#     res = func(*args, **kwargs)
#   File "c:\Program Files\Python310\lib\multiprocessing\process.py", line 140, in kill
#     self._popen.kill()
#   File "c:\Program Files\Python310\lib\multiprocessing\popen_spawn_win32.py", line 123, in terminate
#     _winapi.TerminateProcess(int(self._handle), TERMINATE)
# PermissionError: [WinError 5] Acesso negado
# ---------------------------------------------------------------------------
# KilledWorker                              Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\tpot\base.py:817, in TPOTBase.fit(self, features, target, sample_weight, groups)
#     816         warnings.simplefilter("ignore")
# --> 817         self._pop, _ = eaMuPlusLambda(
#     818             population=self._pop,
#     819             toolbox=self._toolbox,
#     820             mu=self.population_size,
#     821             lambda_=self._lambda,
#     822             cxpb=self.crossover_rate,
#     823             mutpb=self.mutation_rate,
#     824             ngen=self.generations,
#     825             pbar=self._pbar,
#     826             halloffame=self._pareto_front,
#     827             verbose=self.verbosity,
#     828             per_generation_function=self._check_periodic_pipeline,
#     829             log_file=self.log_file_,
#     830         )
#     832 # Allow for certain exceptions to signal a premature fit() cancellation
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tpot\gp_deap.py:232, in eaMuPlusLambda(population, toolbox, mu, lambda_, cxpb, mutpb, ngen, pbar, stats, halloffame, verbose, per_generation_function, log_file)
#     230     initialize_stats_dict(ind)
# --> 232 population[:] = toolbox.evaluate(population)
#     234 record = stats.compile(population) if stats is not None else {}
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tpot\base.py:1568, in TPOTBase._evaluate_individuals(self, population, features, target, sample_weight, groups)
#    1567         warnings.simplefilter("ignore")
# -> 1568         tmp_result_scores = list(dask.compute(*tmp_result_scores, num_workers=self.n_jobs))
#    1570 else:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\dask\base.py:661, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     660 with shorten_traceback():
# --> 661     results = schedule(dsk, keys, **kwargs)
#     663 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File ~\AppData\Roaming\Python\Python310\site-packages\distributed\client.py:2232, in Client._gather(self, futures, errors, direct, local_worker)
#    2231 else:
# -> 2232     raise exception.with_traceback(traceback)
#    2233 raise exc
#
# KilledWorker: Attempted to run task ('bernoullinb-fit-23ed3b110009448cde45d6809a70d93d', 0, 4) on 4 different workers, but all those workers died while running it. The last worker that attempt to run the task was tcp://127.0.0.1:53599. Inspecting worker logs is often a good next step to diagnose what went wrong. For more information see https://distributed.dask.org/en/stable/killed.html.
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 tp.fit(X_train, y_train)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tpot\base.py:864, in TPOTBase.fit(self, features, target, sample_weight, groups)
#     861     except (KeyboardInterrupt, SystemExit, Exception) as e:
#     862         # raise the exception if it's our last attempt
#     863         if attempt == (attempts - 1):
# --> 864             raise e
#     865 return self
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tpot\base.py:855, in TPOTBase.fit(self, features, target, sample_weight, groups)
#     852 if not isinstance(self._pbar, type(None)):
#     853     self._pbar.close()
# --> 855 self._update_top_pipeline()
#     856 self._summary_of_best_pipeline(features, target)
#     857 # Delete the temporary cache before exiting
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tpot\base.py:963, in TPOTBase._update_top_pipeline(self)
#     959             self._last_optimized_pareto_front_n_gens = 0
#     960 else:
#     961     # If user passes CTRL+C in initial generation, self._pareto_front (halloffame) shoule be not updated yet.
#     962     # need raise RuntimeError because no pipeline has been optimized
# --> 963     raise RuntimeError(
#     964         "A pipeline has not yet been optimized. Please call fit() first."
#     965     )
#
# RuntimeError: A pipeline has not yet been optimized. Please call fit() first.
